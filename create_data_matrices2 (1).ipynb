# %% [markdown]
# ## Load packages

# %%
# !mamba install -c nvidia cuda-nvcc
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.1.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['cuda-nvcc']
#
# ...

# %%
# !pip install tables
# Out:
# ...
#   Using cached tables-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
# ...
#   Using cached blosc2-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
# ...
#   Using cached numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...

# %%
# Autoreload packages that are modified
# %load_ext autoreload
# %autoreload 2
import h5py
import os
import sys
import xarray as xr
#import tensorflow as tf
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#if tf.test.is_gpu_available():
    #print('GPU is available')
#else:
    #print('GPU is not available')

#device_name = '/gpu:0'
#ds = xr.open_dataset('forecast_rodeo/data/dataframes/gt-contest_tmax-14d-1979-2018.h5')


####### Initial version #########

# Ensure correct working directory
#if os.path.basename(os.getcwd()) == "experiments":
    #os.chdir(os.path.join("..",".."))
##f1 = h5py.File('data/dataframes/gt-contest_tmax-14d-1979-2018.h5','r')

##Adds 'experiments' folder to path to load experiments_util
#sys.path.insert(0, 'src/experiments')
## Load general utility functions
#from experiments_util import *

######## CloubBucket Hub version ########
import os
import gcsfs
import xarray as xr

#os.environ['PERSISTENT_BUCKET']
#fs = gcsfs.GCSFileSystem()
sys.path.insert(0, 'src/experiments')

if os.path.basename(os.getcwd()) == "experiments":
    os.chdir(os.path.join("..",".."))
from experiments_util2 import *

# %% [markdown]
# ## Create (shared) data matrices
#
# Generates two data matrices containing all needed features that vary by date only (create_date_data) or by date and latitude/longitude (create_lat_lon_date_data) and saves them to results/regression/shared.

# %%
gt_id = "contest_tmp2m" # "contest_precip" or "contest_tmp2m"
target_horizon = "56w" # "34w" or "56w"
experiment = "regression1"
#os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/srv/conda/envs/notebook'
multiflux_resolution = "monthly" #"monthly" or "daily"


date_cols = create_date_data(gt_id, target_horizon, experiment, multiflux_resolution)
lat_lon_date_cols = create_lat_lon_date_data(gt_id, target_horizon, experiment, multiflux_resolution,
                                             forecast_models=["nmme","nmme0"])
# Out:
# Loading date features
# Getting mei_shift59
# Elapsed: 0.3507533073425293s
# Getting mjo_shift31
# Elapsed: 0.17191100120544434s
# Getting pca_sst_2010_shift44
# Elapsed: 0.22885441780090332s
# Getting pca_icec_2010_shift44
# Elapsed: 0.08002138137817383s
# Getting pca_wind_hgt_10_2010_shift44
# Elapsed: 0.13086819648742676s
# Getting pca_wind_hgt_100_2010_shift44
# Elapsed: 0.13170433044433594s
# Getting pca_wind_hgt_500_2010_shift44
# Elapsed: 0.1450965404510498s
# Getting pca_wind_hgt_850_2010_shift44
# Elapsed: 0.22970080375671387s
#              0
# 0   2001-01-01
# 1   2001-02-01
# 2   2001-03-01
# 3   2001-04-01
# 4   2001-05-01
# ..         ...
# 247 2021-08-01
# 248 2021-09-01
# 249 2021-10-01
# 250 2021-11-01
# 251 2021-12-01
#
# [252 rows x 1 columns]
# Elapsed: 9.298324584960938e-06s
#              0
# 0   2001-01-01
# 1   2001-02-01
# 2   2001-03-01
# 3   2001-04-01
# 4   2001-05-01
# ..         ...
# 247 2021-08-01
# 248 2021-09-01
# 249 2021-10-01
# 250 2021-11-01
# ...
